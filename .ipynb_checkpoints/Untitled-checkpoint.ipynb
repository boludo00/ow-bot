# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from pylab import *
import json

# %%
with open('resp.json') as d:
    data = json.loads(d.read())

# %%
data
# Out:
# {u'ALL HEROES': {u'Assists': {u'Healing Done': u'298,434',
#    u'Recon Assists': u'12',
#    u'Teleporter Pads Destroyed': u'12'},
#   u'Average': {u'Damage Done - Average': u'4,608',
#    u'Deaths - Average': u'6.04',
#    u'Eliminations - Average': u'13.2',
#    u'Final Blows - Average': u'7.34',
#    u'Healing Done - Average': u'539',
#    u'Melee Final Blows - Average': u'0.27',
#    u'Objective Kills - Average': u'4.37',
#    u'Objective Time - Average': u'00:31',
#    u'Solo Kills - Average': u'2.69',
#    u'Time Spent on Fire - Average': u'00:37'},
#   u'Best': {u'Damage Done - Most in Game': u'18,329',
#    u'Defensive Assists - Most in Game': u'32',
#    u'Eliminations - Most in Game': u'50',
#    u'Final Blows - Most in Game': u'32',
#    u'Healing Done - Most in Game': u'7,606',
#    u'Multikill - Best': u'5',
#    u'Objective Kills - Most in Game': u'26',
#    u'Objective Time - Most in Game': u'02:03',
#    u'Offensive Assists - Most in Game': u'29',
# ...
